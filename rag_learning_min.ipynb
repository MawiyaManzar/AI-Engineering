# %%
# If needed, uncomment to install:
# !pip install -q sentence-transformers rank-bm25 numpy

import numpy as np
from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
np.random.seed(42)

print("Ready.")

# %%
DOCUMENTS = [
    {"id": 1, "title": "Auth Overview", "content": "OAuth2 with PKCE. Tokens expire in 1 hour. MFA for admins."},
    {"id": 2, "title": "Rate Limits", "content": "Free: 60 rpm. Pro: 600 rpm. Enterprise: 6000 rpm. 429 on exceed."},
    {"id": 3, "title": "Errors", "content": "401 expired token; 429 rate limited; retry with backoff; 500 retry later."},
    {"id": 4, "title": "Monitoring", "content": "Prometheus for metrics, Grafana dashboards, alerts on latency and errors."},
]
doc_texts = [f"{d['title']}. {d['content']}" for d in DOCUMENTS]
print(f"Loaded {len(DOCUMENTS)} docs.")
# Out:
# Loaded 4 docs.
